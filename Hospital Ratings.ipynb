# %% [markdown]
# # Introduction
#
#     In this csv we are going to relate the Hospital rating from data given by Hospital Compare Website provided by the Centers for Medicare & Medicaid Services.These data allow you to compare the quality of care at over 4,000 Medicare-certified hospitals across the country.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hospital = pd.read_csv("Hospital General Information.csv")
hospital.head(25)
# Out:
#     Provider ID                     Hospital Name  \
# 0         10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1         10005     MARSHALL MEDICAL CENTER SOUTH
# 2         10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3         10007          MIZELL MEMORIAL HOSPITAL
# 4         10008       CRENSHAW COMMUNITY HOSPITAL
# 5         10011                 ST VINCENT'S EAST
# 6         10012    DEKALB REGIONAL MEDICAL CENTER
# 7         10016     SHELBY BAPTIST MEDICAL CENTER
# 8         10018             CALLAHAN EYE HOSPITAL
# 9         10019    HELEN KELLER MEMORIAL HOSPITAL
# 10        10021               DALE MEDICAL CENTER
# 11        10022           CHEROKEE MEDICAL CENTER
# 12        10023      BAPTIST MEDICAL CENTER SOUTH
# 13        10024     JACKSON HOSPITAL & CLINIC INC
# 14        10029       EAST ALABAMA MEDICAL CENTER
# 15        10032                  WEDOWEE HOSPITAL
# 16        10033    UNIVERSITY OF ALABAMA HOSPITAL
# 17        10034            COMMUNITY HOSPITAL INC
# ...

# %%
hospital.notnull()
# Out:
#       Provider ID  Hospital Name  Address  City  State  ZIP Code  County Name  \
# 0            True           True     True  True   True      True         True
# 1            True           True     True  True   True      True         True
# 2            True           True     True  True   True      True         True
# 3            True           True     True  True   True      True         True
# 4            True           True     True  True   True      True         True
# ...           ...            ...      ...   ...    ...       ...          ...
# 4807         True           True     True  True   True      True         True
# 4808         True           True     True  True   True      True        False
# 4809         True           True     True  True   True      True        False
# 4810         True           True     True  True   True      True        False
# 4811         True           True     True  True   True      True        False
#
# ...

# %%
hospital.info()
### Here is the information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 28 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Provider ID                                                    4812 non-null   int64
#  1   Hospital Name                                                  4812 non-null   object
#  2   Address                                                        4812 non-null   object
#  3   City                                                           4812 non-null   object
#  4   State                                                          4812 non-null   object
#  5   ZIP Code                                                       4812 non-null   int64
#  6   County Name                                                    4797 non-null   object
# ...

# %%
hospital.describe()
# Out:
#          Provider ID      ZIP Code  Phone Number
# count    4812.000000   4812.000000  4.812000e+03
# mean   268294.422901  53990.132377  5.849100e+09
# std    157109.340215  26915.916870  2.331563e+09
# min     10001.000000    603.000000  9.369338e+08
# 25%    140185.750000  33015.250000  4.015615e+09
# 50%    260043.500000  55410.500000  6.053413e+09
# 75%    390222.250000  76035.500000  7.877574e+09
# max    670118.000000  99929.000000  9.898943e+09

# %%
categorical = [var for var in hospital.columns if hospital[var].dtype=='O']  
categorical
# Out:
# ['Hospital Name',
#  'Address',
#  'City',
#  'State',
#  'County Name',
#  'Hospital Type',
#  'Hospital Ownership',
#  'Emergency Services',
#  'Meets criteria for meaningful use of EHRs',
#  'Hospital overall rating',
#  'Hospital overall rating footnote',
#  'Mortality national comparison',
#  'Mortality national comparison footnote',
#  'Safety of care national comparison',
#  'Safety of care national comparison footnote',
#  'Readmission national comparison',
#  'Readmission national comparison footnote',
#  'Patient experience national comparison',
#  'Patient experience national comparison footnote',
#  'Effectiveness of care national comparison',
#  'Effectiveness of care national comparison footnote',
#  'Timeliness of care national comparison',
#  'Timeliness of care national comparison footnote',
#  'Efficient use of medical imaging national comparison',
#  'Efficient use of medical imaging national comparison footnote']

# %%
sns.heatmap(hospital.isnull(), yticklabels=False, cbar=False, cmap='PiYG_r')
# Out:
# <AxesSubplot:>

# %%
hospital.value_counts()
# Out:
# Provider ID  Hospital Name                                     Address                    City            State  ZIP Code  County Name     Phone Number  Hospital Type              Hospital Ownership                           Emergency Services  Meets criteria for meaningful use of EHRs  Hospital overall rating  Hospital overall rating footnote                                                                                                             Mortality national comparison  Mortality national comparison footnote                                                                                                       Safety of care national comparison  Safety of care national comparison footnote                                                                                                  Readmission national comparison  Readmission national comparison footnote                                                                                                     Patient experience na
# ...

# %% [markdown]
# ## Encoding (strings -> number)
#
# ### As machine learning doesn'tt understand string data we need to convert it into numerical formate that can be done by following process:
# #### 1. Label encoding (0,1)            2.OneHot Encoding (1,2,3....)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
Hospital1 = hospital
Hospital1 = hospital.apply(LabelEncoder().fit_transform)
Hospital1.head()
# Out:
#    Provider ID  Hospital Name  Address  City  State  ZIP Code  County Name  \
# 0            0           3690      470   698      1      1288          666
# 1            1           2231     2113   263      1      1268          877
# 2            2           1107     1725   873      1      1259          801
# 3            3           2583     3920  1928      1      1298          349
# 4            4            917      239  1525      1      1274          359
#
#    Phone Number  Hospital Type  Hospital Ownership  ...  \
# 0          1078              0                   1  ...
# 1           489              0                   1  ...
# 2           492              0                   1  ...
# 3          1066              0                   9  ...
# 4          1060              0                   5  ...
#
#    Readmission national comparison  Readmission national comparison footnote  \
# 0                                3                                         3
# ...

# %%
Hospital1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 28 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Provider ID                                                    4812 non-null   int64
#  1   Hospital Name                                                  4812 non-null   int32
#  2   Address                                                        4812 non-null   int32
#  3   City                                                           4812 non-null   int32
#  4   State                                                          4812 non-null   int32
#  5   ZIP Code                                                       4812 non-null   int64
#  6   County Name                                                    4812 non-null   int32
# ...

# %%
Hospital1.describe()
# Out:
#        Provider ID  Hospital Name      Address         City        State  \
# count  4812.000000    4812.000000  4812.000000  4812.000000  4812.000000
# mean   2405.500000    2323.875104  2385.585619  1450.816708    27.601621
# std    1389.249078    1332.195949  1385.426941   841.216189    15.806506
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%    1202.750000    1170.750000  1186.750000   708.750000    15.000000
# 50%    2405.500000    2340.500000  2384.500000  1456.500000    26.000000
# 75%    3608.250000    3490.250000  3585.250000  2166.250000    41.000000
# max    4811.000000    4622.000000  4783.000000  2946.000000    55.000000
#
#           ZIP Code  County Name  Phone Number  Hospital Type  \
# count  4812.000000  4812.000000   4812.000000    4812.000000
# mean   2229.512884   797.585827   2395.023899       0.579177
# std    1280.769665   431.742167   1383.972581       0.895824
# min       0.000000     0.000000      0.000000       0.000000
# ...

# %%
Hospital1.value_counts()
# Out:
# Provider ID  Hospital Name  Address  City  State  ZIP Code  County Name  Phone Number  Hospital Type  Hospital Ownership  Emergency Services  Meets criteria for meaningful use of EHRs  Hospital overall rating  Hospital overall rating footnote  Mortality national comparison  Mortality national comparison footnote  Safety of care national comparison  Safety of care national comparison footnote  Readmission national comparison  Readmission national comparison footnote  Patient experience national comparison  Patient experience national comparison footnote  Effectiveness of care national comparison  Effectiveness of care national comparison footnote  Timeliness of care national comparison  Timeliness of care national comparison footnote  Efficient use of medical imaging national comparison  Efficient use of medical imaging national comparison footnote
# ...

# %%
hospital1=pd.concat([Hospital1],axis='columns')
hospital1
# Out:
#       Provider ID  Hospital Name  Address  City  State  ZIP Code  County Name  \
# 0               0           3690      470   698      1      1288          666
# 1               1           2231     2113   263      1      1268          877
# 2               2           1107     1725   873      1      1259          801
# 3               3           2583     3920  1928      1      1298          349
# 4               4            917      239  1525      1      1274          359
# ...           ...            ...      ...   ...    ...       ...          ...
# 4807         4811           1214     4581  1206     47      3421          621
# 4808         4741           2055     4629  1966      3      4246         1563
# 4809         4742           1456     4333  2588     12      4251         1563
# 4810         4743           1457      890   651     12      4252         1563
# 4811         4744            825     4749   951     27      4253         1563
#
# ...

# %%
hospital1.corr()
# Out:
#                                                     Provider ID  \
# Provider ID                                            1.000000
# Hospital Name                                          0.012919
# Address                                                0.040806
# City                                                   0.007860
# State                                                  0.989309
# ZIP Code                                              -0.111458
# County Name                                           -0.012182
# Phone Number                                           0.019683
# Hospital Type                                          0.044901
# Hospital Ownership                                     0.044756
# Emergency Services                                     0.040972
# Meets criteria for meaningful use of EHRs              0.041484
# Hospital overall rating                                0.092579
# Hospital overall rating footnote                      -0.062316
# ...

# %%
figure = plt.figure(figsize=(20,20))
sns.heatmap(hospital1.corr(), annot=True , cmap="flag_r")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Graphs

# %%
hospital1.hist(figsize=(30,30),color='red')  #What is the overall grap presentation of hospital comparison
# Out:
# array([[<AxesSubplot:title={'center':'Provider ID'}>,
#         <AxesSubplot:title={'center':'Hospital Name'}>,
#         <AxesSubplot:title={'center':'Address'}>,
#         <AxesSubplot:title={'center':'City'}>,
#         <AxesSubplot:title={'center':'State'}>],
#        [<AxesSubplot:title={'center':'ZIP Code'}>,
#         <AxesSubplot:title={'center':'County Name'}>,
#         <AxesSubplot:title={'center':'Phone Number'}>,
#         <AxesSubplot:title={'center':'Hospital Type'}>,
#         <AxesSubplot:title={'center':'Hospital Ownership'}>],
#        [<AxesSubplot:title={'center':'Emergency Services'}>,
#         <AxesSubplot:title={'center':'Meets criteria for meaningful use of EHRs'}>,
#         <AxesSubplot:title={'center':'Hospital overall rating'}>,
#         <AxesSubplot:title={'center':'Hospital overall rating footnote'}>,
#         <AxesSubplot:title={'center':'Mortality national comparison'}>],
# ...

# %%
sns.pairplot(data=hospital)

# %% [markdown]
# ## Questions :

# %% [markdown]
# #### What type of hospital present in world ?
#
#
# There are 3 types of hospital Acute Care Hospital , Critical Access Hospital and Children.The total number of hospitals are 4812.

# %%
df = pd.DataFrame(hospital['Hospital Type'])
df
# Out:
#              Hospital Type
# 0     Acute Care Hospitals
# 1     Acute Care Hospitals
# 2     Acute Care Hospitals
# 3     Acute Care Hospitals
# 4     Acute Care Hospitals
# ...                    ...
# 4807  Acute Care Hospitals
# 4808  Acute Care Hospitals
# 4809  Acute Care Hospitals
# 4810  Acute Care Hospitals
# 4811  Acute Care Hospitals
#
# [4812 rows x 1 columns]

# %%
hospital['Hospital Type'].unique()
# Out:
# array(['Acute Care Hospitals', 'Critical Access Hospitals', 'Childrens'],
#       dtype=object)

# %%
hospital['Hospital Type'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4807    False
# 4808    False
# 4809    False
# 4810    False
# 4811    False
# Name: Hospital Type, Length: 4812, dtype: bool

# %%
hospital['Hospital Type'].value_counts()
# Out:
# Acute Care Hospitals         3369
# Critical Access Hospitals    1344
# Childrens                      99
# Name: Hospital Type, dtype: int64

# %%
plt.figure(figsize=(5, 10))
hospital['Hospital Type'].hist(bins=5,color='darkred',alpha=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Find the status of each county in csv?

# %%
hospital1
# Out:
#       Provider ID  Hospital Name  Address  City  State  ZIP Code  County Name  \
# 0               0           3690      470   698      1      1288          666
# 1               1           2231     2113   263      1      1268          877
# 2               2           1107     1725   873      1      1259          801
# 3               3           2583     3920  1928      1      1298          349
# 4               4            917      239  1525      1      1274          359
# ...           ...            ...      ...   ...    ...       ...          ...
# 4807         4811           1214     4581  1206     47      3421          621
# 4808         4741           2055     4629  1966      3      4246         1563
# 4809         4742           1456     4333  2588     12      4251         1563
# 4810         4743           1457      890   651     12      4252         1563
# 4811         4744            825     4749   951     27      4253         1563
#
# ...

# %%
hospital['County Name']
# Out:
# 0          HOUSTON
# 1         MARSHALL
# 2       LAUDERDALE
# 3        COVINGTON
# 4         CRENSHAW
#            ...
# 4807        HARRIS
# 4808           NaN
# 4809           NaN
# 4810           NaN
# 4811           NaN
# Name: County Name, Length: 4812, dtype: object

# %%
hospital['County Name'].value_counts()
# Out:
# LOS ANGELES             83
# COOK                    51
# JEFFERSON               47
# WASHINGTON              44
# MONTGOMERY              43
#                         ..
# FAIRBANKS NORTH STAR     1
# OVERTON                  1
# FAUQUIER                 1
# POWELL                   1
# CORTLAND                 1
# Name: County Name, Length: 1563, dtype: int64

# %%
df1 = pd.DataFrame (hospital['County Name'])
df1
# Out:
#      County Name
# 0        HOUSTON
# 1       MARSHALL
# 2     LAUDERDALE
# 3      COVINGTON
# 4       CRENSHAW
# ...          ...
# 4807      HARRIS
# 4808         NaN
# 4809         NaN
# 4810         NaN
# 4811         NaN
#
# [4812 rows x 1 columns]

# %%
df1.isnull()
# Out:
#       County Name
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 4807        False
# 4808         True
# 4809         True
# 4810         True
# 4811         True
#
# [4812 rows x 1 columns]

# %%
df1.count()
# Out:
# County Name    4797
# dtype: int64

# %%
plt.figure(figsize = (10, 8)) 
sns.countplot(y = 'County Name', hue = 'State', data = hospital)
plt.ylabel('County')
plt.xlabel('State')
# Out:
# Text(0.5, 0, 'State')

# %%
hospital1['Provider ID'].unique()
# Out:
# array([   0,    1,    2, ..., 4742, 4743, 4744], dtype=int64)

# %%
hospital['Provider ID'].count()
# Out:
# 4812

# %%
hospital['Provider ID'].value_counts()
# Out:
# 141313    1
# 171365    1
# 171361    1
# 200031    1
# 50526     1
#          ..
# 60112     1
# 111311    1
# 230093    1
# 230089    1
# 141311    1
# Name: Provider ID, Length: 4812, dtype: int64

# %%
plt.figure(figsize = (15, 20)) 
sns.countplot(y = 'Provider ID', hue = 'Hospital Name', data = hospital)
plt.ylabel('Provider ID')
plt.xlabel('Hospital Name')

# %%
plt.figure(figsize=(20,15))
sns.distplot(hospital1['State'].dropna(),kde=True,color='darkred',bins=20)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Density'>

# %%
plt.figure(figsize = (30 , 10))
sns.set_style('whitegrid')
sns.countplot(x='Provider ID',hue='Hospital Type',data=hospital1,palette='rainbow')

# %%
plt.figure(figsize=(30, 10))
hospital['Hospital Ownership'].hist(bins=5,color='darkred',alpha=0.9)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(30, 10))
hospital1['City'].hist(bins=5,color='blue',alpha=0.9,)
# Out:
# <AxesSubplot:>

# %%
hospital1['Efficient use of medical imaging national comparison footnote'].unique
# Out:
# <bound method Series.unique of 0       3
# 1       3
# 2       3
# 3       2
# 4       2
#        ..
# 4807    2
# 4808    2
# 4809    2
# 4810    0
# 4811    2
# Name: Efficient use of medical imaging national comparison footnote, Length: 4812, dtype: int32>

# %%
hospital['Efficient use of medical imaging national comparison footnote'].count
# Out:
# <bound method Series.count of 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3       Results are not available for this reporting p...
# 4       Results are not available for this reporting p...
#                               ...
# 4807    Results are not available for this reporting p...
# 4808    Results are not available for this reporting p...
# 4809    Results are not available for this reporting p...
# 4810    Data are shown only for hospitals that partici...
# 4811    Results are not available for this reporting p...
# Name: Efficient use of medical imaging national comparison footnote, Length: 4812, dtype: object>

# %%
hospital1['Efficient use of medical imaging national comparison footnote'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4807    False
# 4808    False
# 4809    False
# 4810    False
# 4811    False
# Name: Efficient use of medical imaging national comparison footnote, Length: 4812, dtype: bool

# %%
hospital
# Out:
#       Provider ID                     Hospital Name  \
# 0           10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1           10005     MARSHALL MEDICAL CENTER SOUTH
# 2           10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3           10007          MIZELL MEMORIAL HOSPITAL
# 4           10008       CRENSHAW COMMUNITY HOSPITAL
# ...           ...                               ...
# 4807       670118              FIRST TEXAS HOSPITAL
# 4808       640001       LBJ TROPICAL MEDICAL CENTER
# 4809       650001  GUAM MEMORIAL HOSPITAL AUTHORITY
# 4810       650003        GUAM REGIONAL MEDICAL CITY
# 4811       660001        COMMONWEALTH HEALTH CENTER
#
#                             Address       City State  ZIP Code County Name  \
# 0            1108 ROSS CLARK CIRCLE     DOTHAN    AL     36301     HOUSTON
# 1        2505 U S HIGHWAY 431 NORTH       BOAZ    AL     35957    MARSHALL
# 2                205 MARENGO STREET   FLORENCE    AL     35631  LAUDERDALE
# ...

# %% [markdown]
# # Conclusion
#
# Here we data is in huge amount about hospital .There are many missing date present in the csv.There for there are good types of hospital are present in county and data about their specification.

# %% [markdown]
# # Thank You
